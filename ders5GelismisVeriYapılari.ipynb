# %% [markdown]
# <center>
# <div style="background: linear-gradient(135deg, #2563eb, #1d4ed8, #3b82f6);
#             color:white;
#             padding:28px;
#             border-radius:20px;
#             font-size:38px;
#             font-weight:900;
#             font-family:'Trebuchet MS', sans-serif;
#             letter-spacing:1.5px;
#             text-shadow:2px 2px 8px rgba(0,0,0,0.3);
#             box-shadow: 3px 3px 12px rgba(0,0,0,0.25);
#             width:fit-content;">
# 💻🧠 PROGRAMLAMAYA GİRİŞ – DERS 5
# </div>
# </center>

# %% [markdown]
# ## 🚀 GELİŞMİŞ VERİ YAPILARI
#
# ---
#
# ## 📚 İÇİNDEKİLER
#
# ### 🔹 1. Listeler (List)
# - Listelerin tanımı
# - Listelerin kullanım amacı
# - Liste oluşturma yöntemleri
# - Liste elemanlarına erişim
# - İndeksleme ve negatif indeksler
# - Liste dilimleme (slicing)
# - Listeye eleman ekleme
#   - `append()`
#   - `insert()`
#   - `extend()`
# - Listeden eleman silme
#   - `remove()`
#   - `pop()`
#   - `del`
# - Liste üzerinde döngü kullanımı
# - İç içe listeler
# - Liste metodları
# - Liste kullanımıyla ilgili örnekler
#
# ---
#
# ### 🔹 2. Demetler (Tuple)
# - Tuple nedir?
# - Tuple oluşturma
# - Tuple elemanlarına erişim
# - İndeksleme ve dilimleme
# - Tuple ile liste arasındaki farklar
# - Tuple’ların değiştirilemez yapısı (immutable)
# - Tuple kullanım alanları
# - Tuple ile çoklu değer döndürme
# - Tuple örnekleri
#
# ---
#
# ### 🔹 3. Sözlükler (Dictionary)
# - Dictionary nedir?
# - Anahtar–değer (key–value) mantığı
# - Dictionary oluşturma
# - Dictionary elemanlarına erişim
# - Eleman ekleme ve güncelleme
# - Eleman silme
# - Dictionary üzerinde döngü kullanımı
# - `keys()` metodu
# - `values()` metodu
# - `items()` metodu
# - İç içe dictionary yapıları
# - Dictionary kullanım örnekleri
#
# ### 🔹 4. Kümeler (Set)
# - Set nedir?
# - Set oluşturma
# - Set özellikleri (tekrarsız ve sırasız yapı)
# - Set elemanlarına erişim
# - Set’e eleman ekleme
#   - `add()`
#   - `update()`
# - Set’ten eleman silme
#   - `remove()`
#   - `discard()`
#   - `pop()`
# - Set işlemleri
#   - Birleşim (union)
#   - Kesişim (intersection)
#   - Fark (difference)
# - Set kullanım örnekleri

# %% [markdown]
# <h1 style="
# background: linear-gradient(135deg, #b6d3f2, #9fc3eb);
# color:#081f33;
# padding:26px 28px;
# border-radius:22px;
# font-weight:1000;
# font-size:42px;
# letter-spacing:1.2px;
# text-transform:uppercase;
# box-shadow: 4px 4px 14px rgba(0,0,0,0.18);
# border-left:10px solid #1e4f91;">
# 📘 LİSTELER (LIST)
# </h1>

# %% [markdown]
# <h2 style="
# background-color:#e8f1f8;
# color:#1e3a5f;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📘 Listelerin Özellikleri
# </h2>
#
# - **Veri Tipi:** `list`
#
# - **Sıralıdır (Ordered)**
#   Liste elemanları eklenme sırasına göre tutulur.
#
# - **Değiştirilebilir (Mutable)**
#   Liste elemanları sonradan değiştirilebilir, eklenebilir veya silinebilir.
#
# - **İndeksleme Yapılabilir**
#   Elemanlara indeks numarası ile erişilir.
#   - Pozitif indeksler: `0, 1, 2, ...`
#   - Negatif indeksler: `-1, -2, ...`
#
# - **Farklı Veri Tiplerini Tutabilir**
#   Aynı liste içerisinde farklı veri tipleri birlikte bulunabilir.
#
# - **Tekrarlı Elemanlara İzin Verir**
#   Aynı değer listede birden fazla kez yer alabilir.
#
# - **İç İçe Listeler Oluşturulabilir**
#   Bir listenin elemanı başka bir liste olabilir.
#
# - **Dinamik Yapıya Sahiptir**
#   Eleman sayısı sabit değildir, program çalışırken değişebilir.
#
# - **Döngülerle Kolay Kullanılır**
#   `for` ve `while` döngüleri ile liste üzerinde rahatça işlem yapılabilir.
#
# - **Zengin Metod Desteği Vardır**
#   `append()`, `insert()`, `remove()`, `pop()`, `sort()`, `reverse()` gibi birçok hazır metoda sahiptir.

# %% [markdown]
# <h2 style="
# background-color:#e8f1f8;
# color:#1e3a5f;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📘 Listeler Oluşturma
# </h2>

# %%
#Boş bir liste oluşturma
N=[]
type(N)
# Out:
# list

# %%
#List Tipini Kullanarak Liste Oluşturma
N=list()
type(N)
# Out:
# list

# %%
N=[90,"d",8.7]
M=[1,4,N]
M
#[1, 4, [90, 'd', 8.7]]
# Out:
# [1, 4, [90, 'd', 8.7]]

# %% [markdown]
# <h2 style="
# background-color:#e8f1f8;
# color:#1e3a5f;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📘 Listelerin Eleman Sayısını Bulma
# </h2>

# %%
N=[90,"d",8.7]
len(N)
N.count(90) #kaç 90 var sayar
# Out:
# 1

# %% [markdown]
# <h2 style="
# background-color:#e8f1f8;
# color:#1e3a5f;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📘 Listeler Elemana Erişme
# </h2>

# %%
N=[90,"d",8.7]
N[0]
# Out:
# 90

# %%
N=[90,"d",8.7]
N[0:2] #0. indisten
# Out:
# [90, 'd']

# %%
N=[90,"d",8.7]
N[:2]
# Out:
# [90, 'd']

# %%
N=[90,"d",8.7]
N[2:]
# Out:
# [8.7]

# %%
N=[90,"d",8.7]
M=[1,4,N]
print(M)
M[2][1]
# Out:
# [1, 4, [90, 'd', 8.7]]
# 'd'

# %% [markdown]
# <div style="font-family: Arial, sans-serif; line-height: 1.6;">
#
#   <h2 style="color:#2c3e50;">
#     🐍 <span style="color:#27ae60;">Python</span> – Döngüler ve Listeler
#   </h2>
#
#   <hr>
#
#   <h3 style="color:#2980b9;">
#     ❓ Soru
#   </h3>
#
#   <p>
#     Aşağıda belirtilen adımlara göre bir <b>Python programı</b> yazmanız istenmektedir:
#   </p>
#
#   <ul>
#     <li>📌 Sayılardan oluşan bir <span style="color:#8e44ad;"><b>liste</b></span> oluşturunuz.</li>
#     <li>🔁 Bu listeyi bir <span style="color:#16a085;"><b>döngü</b></span> kullanarak kontrol ediniz.</li>
#     <li>🛑 Liste içerisinde <span style="color:red;"><b>96</b></span> sayısı bulunduğu anda döngüyü durdurunuz.</li>
#     <li>🖨️ 96 sayısı bulunana kadar dolaşılan elemanları ekrana yazdırınız.</li>
#     <li>✅ 96 bulunduğunda kullanıcıya bilgilendirici bir mesaj gösteriniz.</li>
#   </ul>
#
#   <h3 style="color:#e67e22;">
#     💡 İpuçları
#   </h3>
#
#   <ul>
#     <li>➡️ <code>for</code> döngüsünü kullanabilirsiniz.</li>
#     <li>➡️ Döngüyü durdurmak için uygun anahtar kelimeyi araştırınız.</li>
#   </ul>
#
#   <div style="background-color:#fce4ec; padding:10px; border-left:5px solid #e91e63;">
#     ⚠️ <b>Not:</b>
#     96 sayısı bulunduğu anda döngü sonlanmalı ve listenin geri kalan elemanları kontrol edilmemelidir.
#   </div>
#
# </div>

# %%
N=[54,6,5,321,95,96,66,5,2,3,4]

# %% [markdown]
# <h2 style="
# background-color:#e8f1f8;
# color:#1e3a5f;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📘 Listelerde Eleman Silme
# </h2>

# %%
N=[90,"d",8.7]
print(N)
del N[0] # 0.indeks silinir.
print(N)
# Out:
# [90, 'd', 8.7]
# ['d', 8.7]

# %%
N=[90,"d",8.7]
print(N)
del N # Tüm liste sil
print(N) #N artık yok
# Out:
# [90, 'd', 8.7]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 4
#       2 print(N)
#       3 del N # Tüm liste sil
# ----> 4 print(N)
#
# NameError: name 'N' is not defined

# %%
N=[90,"d",8.7]
print(N)
N.remove(90) 
print(N)
# Out:
# [90, 'd', 8.7]
# ['d', 8.7]

# %%
N=[90,"d",8.7]
print(N)
N.pop(0)# 0. İndeksi siler
print(N)
# Out:
# [90, 'd', 8.7]
# ['d', 8.7]

# %% [markdown]
# <h2 style="
# background-color:#e8f1f8;
# color:#1e3a5f;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📘 Listelerdeki Elemanları Ekrana Yazdırma
# </h2>

# %%
N=[90,"d",8.7]
print(N)
# Out:
# [90, 'd', 8.7]

# %% [markdown]
# <h2 style="
# background-color:#e8f1f8;
# color:#1e3a5f;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📘 Listelerdeki Elemanı Değiştirme
# </h2>

# %%
N=[90,"d",8.7]
N[0:2]=1,1
N
# Out:
# [1, 1, 8.7]

# %% [markdown]
# ```python
# N = [90, "d", 8.7]
#
# # Dilimleme (slice) ifadesi
# N[0:2] = 1, 1
# # 0:2 demek: 0. indexten başla, 2. indexe kadar git ama 2. index dahil değil
# # Yani N[0] ve N[1] elemanlarını seçer: [90, 'd']
#
# # Sağ taraf: 1, 1
# # Bu aslında bir tuple: (1, 1)
# # Python bunu sağdaki değerler olarak alır ve sol taraftaki dilime yerleştirir.
#
# # Sonuç
# # N[0] ve N[1] yerine 1, 1 konuyor.
# # Yani [90, 'd'] → [1, 1]
#
# # Listenin son hali:
# N  # [1, 1, 8.7]

# %%
#N + ["k"] ifadesi, mevcut N listesinin sonuna "k" elemanını ekleyen yeni bir liste oluşturur.
N = [90, 'd', 8.7]
N = N + ["k"]
print(N)  # [90, 'd', 8.7, 'k']
# Out:
# [90, 'd', 8.7, 'k']

# %%
#.append() metodu, listeye her zaman bir elemanı sonuna ekler.
N.append(6)
print(N)  # [90, 'd', 8.7, 'k', 6]
# Out:
# [90, 'd', 8.7, 'k', 6]

# %%
#.insert(index, eleman) metodu, belirtilen indekse eleman ekler.
N.insert(0, 6)
print(N)  # [6, 90, 'd', 8.7, 'k', 6]
# Out:
# [6, 90, 'd', 8.7, 'k', 6]

# %%
#len(N) listenin uzunluğunu verir, yani son indeksi +1 yapar. Bu, listenin sonuna eklemek ile aynı şeydir:
N.insert(len(N), "k")
print(N)  # [6, 90, 'd', 8.7, 'k', 6, 'k']
# Out:
# [6, 90, 'd', 8.7, 'k', 6, 'k']

# %%
#.reverse() metodu, listeyi tersine çevirir.
N.reverse()
print(N)  # ['k', 6, 'k', 8.7, 'd', 90, 6]
# Out:
# ['k', 6, 'k', 8.7, 'd', 90, 6]

# %%
#.copy() metodu, listenin bağımsız bir kopyasını oluşturur.
M = N.copy()
print(M)  # ['k', 6, 'k', 8.7, 'd', 90, 6]
# Out:
# ['k', 6, 'k', 8.7, 'd', 90, 6]

# %%
#.index(eleman) metodu, elemanın ilk bulunduğu indeksi verir.
N.index(90)  # 5
# Out:
# 5

# %%
#.sort() metodu, aynı türdeki verileri sıralar (örn. hepsi sayılar veya hepsi string).
#Karışık türlerde (sayı ve string) çalışmaz, hata verir.
nums = [5, 1, 8]
nums.sort()
print(nums)  # [1, 5, 8]
# Out:
# [1, 5, 8]

# %%
#.extend() metodu, listeye başka bir listeyi ekler (eleman eleman).
N.extend([1, 2, 3])
print(N)  # [1, 2, 3]
# Out:
# ['k', 6, 'k', 8.7, 'd', 90, 6, 1, 2, 3]

# %% [markdown]
# ## Özetle:
#
# append → tek eleman ekler
#
# extend → listeyi birleştirir
#
# insert → istediğin indekse eleman ekler
#
# reverse → listeyi tersine çevirir
#
# copy → bağımsız kopya oluşturur
#
# index → elemanın konumunu verir
#
# sort → aynı türden elemanları sıralar
#
# clear → listeyi temizler

# %% [markdown]
# <h1 style="
# background: linear-gradient(135deg, #e0cfae, #cdb58d);
# color:#2a1c0f;
# padding:26px 28px;
# border-radius:22px;
# font-weight:1000;
# font-size:42px;
# letter-spacing:1.2px;
# text-transform:uppercase;
# box-shadow: 4px 4px 14px rgba(0,0,0,0.18);
# border-left:10px solid #7a5a2a;">
# 📗 DEMETLER (TUPLE)
# </h1>

# %% [markdown]
# <h2 style="
# background-color:#f3efe8;
# color:#5a4632;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📗 Demetlerin Özellikleri
# </h2>
#
# - **Veri Tipi:** `tuple`
#
# - **Sıralıdır (Ordered)**
#   Demet elemanları oluşturuldukları sıraya göre tutulur.
#
# - **Değiştirilemez (Immutable)**
#   Demet elemanları oluşturulduktan sonra değiştirilemez, eklenemez veya silinemez.
#
# - **İndeksleme Yapılabilir**
#   Elemanlara indeks numarası ile erişilir.
#   - Pozitif indeksler: `0, 1, 2, ...`
#   - Negatif indeksler: `-1, -2, ...`
#
# - **Farklı Veri Tiplerini Tutabilir**
#   Aynı demet içerisinde farklı veri tipleri birlikte bulunabilir.
#
# - **Tekrarlı Elemanlara İzin Verir**
#   Aynı değer demet içerisinde birden fazla kez yer alabilir.
#
# - **Daha Güvenli Bir Yapıdır**
#   Veriler değiştirilemediği için yanlışlıkla veri değiştirme riski yoktur.
#
# - **Daha Hızlıdır**
#   Değiştirilemez yapıda olduğu için listelere göre daha performanslıdır.
#
# - **Parantez ile Tanımlanır**
#   Küçük parantez `()` kullanılarak oluşturulur.
#
# - **Fonksiyonlarda Çoklu Değer Döndürmek İçin Kullanılır**
#   Bir fonksiyon birden fazla değeri `tuple` olarak döndürebilir.

# %% [markdown]
# <h2 style="
# background-color:#f3efe8;
# color:#5a4632;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📗 Demetlerin  Oluşturulması
# </h2>

# %%
T=("ali",4,7.2,[4,5,6])
('ali', 4, 7.2, [4, 5, 6])
T=("ali",)
#tek elemanlıda yanına virgül konur

# %% [markdown]
# <h2 style="
# background-color:#f3efe8;
# color:#5a4632;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📗 Demetlerin Eleman Sayısını Bulma
# </h2>

# %%
T=("ali",4,7.2,[4,5,6])
len(T) # Çıktı: 4
# Out:
# 4

# %% [markdown]
# <h2 style="
# background-color:#f3efe8;
# color:#5a4632;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📗 Demetler Elemana Erişme
# </h2>

# %%
T=("ali",4,7.2,[4,5,6])
T[0]
# Out:
# 'ali'

# %%
T=("ali",4,7.2,[4,5,6])
T[0:2]
# Out:
# ('ali', 4)

# %%
T=("ali",4,7.2,[4,5,6])
T[:2]
# Out:
# ('ali', 4)

# %%
T=("ali",4,7.2,[4,5,6])
T[2:]
# Out:
# (7.2, [4, 5, 6])

# %%
T=("ali",4,7.2,[4,5,6])
T[3][1]
# Out:
# 5

# %% [markdown]
# <h2 style="
# background-color:#f3efe8;
# color:#5a4632;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📗 Demetler Eleman Silme
# </h2>

# %%
T=("ali",4,7.2,[4,5,6])
del T[0] # Hata verir, çünkü tuple elemanları silinemez.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 2
#       1 T=("ali",4,7.2,[4,5,6])
# ----> 2 del T[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
T=("ali",4,7.2,[4,5,6])
del T # Tuple’ın kendisi silinebilir, bu tüm nesneyi bellekten kaldırır.
print(T) #artık bu tuple yok
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 3
#       1 T=("ali",4,7.2,[4,5,6])
#       2 del T # Tuple’ın kendisi silinebilir, bu tüm nesneyi bellekten kaldırır.
# ----> 3 print(T)
#
# NameError: name 'T' is not defined

# %%
T=("ali",4,7.2,[4,5,6])
T[3].remove(4) # Mümkün, çünkü T[3] bir liste. Bu işlem liste içindeki '4' elemanını kaldırır.
print(T)
# Out:
# ('ali', 4, 7.2, [5, 6])

# %%
T=("ali",4,7.2,[4,5,6])
T[3].pop(0) # Mümkün, çünkü T[3] bir liste. Bu işlem listenin ilk elemanını (şu anki haliyle) kaldırır.
print(T)
# Out:
# ('ali', 4, 7.2, [5, 6])

# %% [markdown]
# <h2 style="
# background-color:#f3efe8;
# color:#5a4632;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📗 Demetlerdeki Elemanları Ekrana Yazdırma
# </h2>

# %%
T=("ali",4,7.2,[4,5,6])
print(T)
# Out:
# ('ali', 4, 7.2, [4, 5, 6])

# %% [markdown]
# <h2 style="
# background-color:#f3efe8;
# color:#5a4632;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📗 Demetlerdeki Elemanları Değiştirme
# </h2>

# %%
T=("ali",4,7.2,[4,5,6])
T[3][1] = 10
# Mümkün
T
# Out:
# ('ali', 4, 7.2, [4, 10, 6])

# %% [markdown]
# ```python
# T = ("ali", 4, 7.2, [4, 5, 6])
#
# # Tuple’lar immutable yani değiştirilemez.
# # Örneğin T[0] = "mehmet" gibi bir atama yapılamaz.
#
# # Ama tuple içindeki mutable (değiştirilebilir) nesneler değiştirilebilir.
# # Tuple’ı değiştirmiyoruz, sadece tuple içindeki listenin içeriğini değiştiriyoruz.
#
# # Mutable örnekleri: list, dict, set
# # Burada T[3] bir liste [4,5,6] → mutable

# %%
T=("ali",4,7.2,[4,5,6])
T[0] = "ahmet"
# Hata verir: TypeError:'tuple' object does not support item assignment
# Tuple’lar immutable yani değiştirilemez.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 2
#       1 T=("ali",4,7.2,[4,5,6])
# ----> 2 T[0] = "ahmet"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# <h1 style="
# background: linear-gradient(135deg, #e7c6d8, #d8a9c4);
# color:#3a1026;
# padding:26px 28px;
# border-radius:22px;
# font-weight:1000;
# font-size:42px;
# letter-spacing:1.2px;
# text-transform:uppercase;
# box-shadow: 4px 4px 14px rgba(0,0,0,0.18);
# border-left:10px solid #8b2c5c;">
# 📕 SÖZLÜKLER (DICTIONARY)
# </h1>

# %% [markdown]
# <h2 style="
# background-color:#f5e3ec;
# color:#6a1f45;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📕 Sözlüklerin  Özellikleri
# </h2>
#
# - **Veri Tipi:** `dict`
#
# - **Anahtar–Değer Yapısına Sahiptir (Key–Value)**
#   Veriler anahtar (key) ve ona karşılık gelen değer (value) şeklinde tutulur.
#
# - **Sırasızdır**
#   Elemanlar indeksle değil anahtar ile erişilir. *(Mantıksal sıra yoktur.)*
#
# - **Değiştirilebilir (Mutable)**
#   Sözlük elemanları eklenebilir, güncellenebilir veya silinebilir.
#
# - **Anahtarlar Benzersizdir (Unique)**
#   Aynı anahtar bir sözlükte birden fazla kez bulunamaz.
#
# - **Değerlere Erişim Anahtar Üzerinden Yapılır**
#   İndeksleme yoktur, erişim anahtar adı ile sağlanır.
#
# - **Farklı Veri Tiplerini Destekler**
#   Anahtarlar ve değerler farklı veri tiplerinde olabilir.
#
# - **Hızlı Veri Erişimi Sağlar**
#   Anahtar tabanlı yapı sayesinde arama işlemleri hızlıdır.
#
# - **Süslü Parantez ile Tanımlanır**
#   `{}` kullanılarak oluşturulur.
#
# - **İç İçe Dictionary Yapıları Oluşturulabilir**
#   Bir sözlüğün değeri başka bir sözlük olabilir.
#
# - **Zengin Metod Desteği Vardır**
#   `keys()`, `values()`, `items()`, `get()`, `pop()` gibi metodlar içerir.

# %% [markdown]
# <h2 style="
# background-color:#f5e3ec;
# color:#6a1f45;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📕 Sözlüklerin Oluşturulması
# </h2>

# %%
S={15:"Burdur",13:"Bitlis",34:"İstanbul"}
#Ç {15: 'Burdur', 13: 'Bitlis',34: 'İstanbul'}
S1={
    15:{100:"Burdur",200:"Bucak",},
    13:{130:"Bitlis",230:"Tatvan"},
    34:{400:"İstanbul",440:"Esenyurt"}
}

# %% [markdown]
# <h2 style="
# background-color:#f5e3ec;
# color:#6a1f45;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📕 Sözlüklerin Eleman Sayısını Bulma
# </h2>

# %%
ad="naaciye"
S=set(ad)
len(S) #6
# Out:
# 6

# %% [markdown]
# <h2 style="
# background-color:#f5e3ec;
# color:#6a1f45;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📕 Sözlükler Elemana Erişme
# </h2>

# %%
S={15:"Burdur",13:"Bitlis",34:"İstanbul"}
S[15]
# Out:
# 'Burdur'

# %%
S1={15:{100:"Burdur",200:"Bucak",},
    13:{130:"Bitlis",230:"Tatvan"},
    34:{400:"İstanbul",440:"Esenyurt"}
}
S1[15][100]
# Out:
# 'Burdur'

# %% [markdown]
# <h2 style="
# background-color:#f5e3ec;
# color:#6a1f45;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📕 Sözlükler Eleman Silme
#
# </h2>

# %%
S1={15:{100:"Burdur",200:"Bucak",},
    13:{130:"Bitlis",230:"Tatvan"},
    34:{400:"İstanbul",440:"Esenyurt"}
}
# 1. Belirli bir anahtarı silme
del S1[13] # Ç: {15: "Burdur", 34: "İstanbul"}
S1
# Out:
# {15: {100: 'Burdur', 200: 'Bucak'}, 34: {400: 'İstanbul', 440: 'Esenyurt'}}

# %%
S1={15:{100:"Burdur",200:"Bucak",},
    13:{130:"Bitlis",230:"Tatvan"},
    34:{400:"İstanbul",440:"Esenyurt"}
}
bitlis = S1.pop(13) # 13 anahtarı ve değeri silinir, değeri döner 
print(bitlis)
print(S1)
# Out:
# {130: 'Bitlis', 230: 'Tatvan'}
# {15: {100: 'Burdur', 200: 'Bucak'}, 34: {400: 'İstanbul', 440: 'Esenyurt'}}

# %%
S1={15:{100:"Burdur",200:"Bucak",},
    13:{130:"Bitlis",230:"Tatvan"},
    34:{400:"İstanbul",440:"Esenyurt"}
}

sondan_silinen = S1.popitem() # Sözlükte kalan son çift silinir
print(S1) # Ç:{15: 'Burdur', 13: 'Bitlis'}
print(sondan_silinen)
# Out:
# {15: {100: 'Burdur', 200: 'Bucak'}, 13: {130: 'Bitlis', 230: 'Tatvan'}}
# (34, {400: 'İstanbul', 440: 'Esenyurt'})

# %%
S1={15:{100:"Burdur",200:"Bucak",},
    13:{130:"Bitlis",230:"Tatvan"},
    34:{400:"İstanbul",440:"Esenyurt"}
}

S1.clear() # Tüm elemanları temizler
print(S1)
# Out:
# {}

# %%
S1={15:{100:"Burdur",200:"Bucak",},
    13:{130:"Bitlis",230:"Tatvan"},
    34:{400:"İstanbul",440:"Esenyurt"}
}

del S1 # Sözlük tamamen silinir
print(S1)
# Hata verir: NameError: name 'S1' is not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 7
#       1 S1={15:{100:"Burdur",200:"Bucak",},
#       2     13:{130:"Bitlis",230:"Tatvan"},
#       3     34:{400:"İstanbul",440:"Esenyurt"}
#       4 }
#       6 del S1 # Sözlük tamamen silinir
# ----> 7 print(S1)
#
# NameError: name 'S1' is not defined

# %% [markdown]
# <h2 style="
# background-color:#f5e3ec;
# color:#6a1f45;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📕 Sözlüklerdeki Elemanları Ekrana Yazdırma
#
# </h2>

# %%
S1={15:{100:"Burdur",200:"Bucak",},
    13:{130:"Bitlis",230:"Tatvan"},
    34:{400:"İstanbul",440:"Esenyurt"}
}
print(S1)
#{15: 'Burdur', 13: 'Bitlis', 34: 'İstanbul'}
# Out:
# {15: {100: 'Burdur', 200: 'Bucak'}, 13: {130: 'Bitlis', 230: 'Tatvan'}, 34: {400: 'İstanbul', 440: 'Esenyurt'}}

# %% [markdown]
# <h2 style="
# background-color:#f5e3ec;
# color:#6a1f45;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📕 Sözlüklerdeki Elemanların Değiştirilmesi
#
# </h2>

# %%
S1={15:{100:"Burdur",200:"Bucak",},
    13:{130:"Bitlis",230:"Tatvan"},
    34:{400:"İstanbul",440:"Esenyurt"}
}
S1[6]="Ankara"
#{15: 'Burdur', 13: 'Bitlis', 34: 'İstanbul', 6: 'Ankara'}
#key değerin aynısı yoksa eklemevarsa veriye erişme
#sözel değerlerde key olabilir.
S1
# Out:
# {15: {100: 'Burdur', 200: 'Bucak'},
#  13: {130: 'Bitlis', 230: 'Tatvan'},
#  34: {400: 'İstanbul', 440: 'Esenyurt'},
#  6: 'Ankara'}

# %%
S1[6] = "Ankara, Başkent"  # Mevcut key'in değeri güncellenir
print(S1)               # Ankara, Başkent
# Out:
# {15: {100: 'Burdur', 200: 'Bucak'}, 13: {130: 'Bitlis', 230: 'Tatvan'}, 34: {400: 'İstanbul', 440: 'Esenyurt'}, 6: 'Ankara, Başkent'}

# %%
#update() ile Birden Fazla Veri Ekleme
S1.update({7: "Antalya", 16: "Bursa"})
print(S1)
# Out:
# {15: {100: 'Burdur', 200: 'Bucak'}, 13: {130: 'Bitlis', 230: 'Tatvan'}, 34: {400: 'İstanbul', 440: 'Esenyurt'}, 6: 'Ankara, Başkent', 7: 'Antalya', 16: 'Bursa'}

# %%
#setdefault() ile Ekleme
S1.setdefault(1, "Adana")  # Key yoksa ekler
S1.setdefault(34, "Deneme")  # Key var, değiştirmez
print(S1)
# Out:
# {15: {100: 'Burdur', 200: 'Bucak'}, 13: {130: 'Bitlis', 230: 'Tatvan'}, 34: {400: 'İstanbul', 440: 'Esenyurt'}, 6: 'Ankara, Başkent', 7: 'Antalya', 16: 'Bursa', 1: 'Adana'}

# %%
#İç İçe Sözlükte Veri Ekleme

S1[6][300] = 'Kızılcahamam'  # 6 key'inin alt sözlüğüne yeni veri ekledik
print(S1)  # {100:'Burdur', 200:'Bucak', 300:'Kızılcahamam'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[88], line 2
#       1 #İç İçe Sözlükte Veri Ekleme
# ----> 2 S1[6][300] = 'Kızılcahamam'  # 6 key'inin alt sözlüğüne yeni veri ekledik
#       3 print(S1)
#
# TypeError: 'str' object does not support item assignment

# %%
#İç İçe Sözlükte Veri Ekleme
#Stringler mutable (değiştirilebilir) değildir → index ile değer atayamazsın
#Bu yüzden Python TypeError verir:
S1[6] = {}               # 6 key'ine boş sözlük atıyoruz
S1[6][300] = 'Kızılcahamam'  # 6 key'inin alt sözlüğüne yeni veri ekledik
print(S1)  # {100:'Burdur', 200:'Bucak', 300:'Kızılcahamam'}
# Out:
# {15: {100: 'Burdur', 200: 'Bucak'}, 13: {130: 'Bitlis', 230: 'Tatvan'}, 34: {400: 'İstanbul', 440: 'Esenyurt'}, 6: {300: 'Kızılcahamam'}, 7: 'Antalya', 16: 'Bursa', 1: 'Adana'}

# %% [markdown]
# <h1 style="
# background: linear-gradient(135deg, #bfe2cf, #a4d3b8);
# color:#0f2e22;
# padding:26px 28px;
# border-radius:22px;
# font-weight:1000;
# font-size:42px;
# letter-spacing:1.2px;
# text-transform:uppercase;
# box-shadow: 4px 4px 14px rgba(0,0,0,0.18);
# border-left:10px solid #1f6b4f;">
# 📙 KÜMELER (SET)

# %% [markdown]
# <h2 style="
# background-color:#eef6f1;
# color:#1f4d3a;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📙 Kümelerin Özellikleri
# </h2>
#
# - **Veri Tipi:** `set`
#
# - **Sırasızdır (Unordered)**
#   Küme elemanlarının belirli bir sırası yoktur.
#
# - **Tekrarsızdır (Unique)**
#   Aynı eleman küme içinde sadece **bir kez** bulunabilir.
#
# - **Değiştirilebilir (Mutable)**
#   Küme elemanları eklenebilir veya silinebilir.
#
# - **İndeksleme Yoktur**
#   Elemanlara indeks numarası ile erişilemez.
#
# - **Farklı Veri Tiplerini Tutabilir**
#   Aynı küme içerisinde farklı veri tipleri bulunabilir.
#
# - **Hızlı Arama Yapısıdır**
#   Eleman var mı yok mu kontrolü çok hızlıdır.
#
# - **Süslü Parantez ile Tanımlanır**
#   `{}` kullanılarak oluşturulur.
#
# - **Küme İşlemleri Destekler**
#   - Birleşim (union)
#   - Kesişim (intersection)
#   - Fark (difference)
#
# - **Matematiksel Küme Mantığına Uygundur**
#   Matematikteki küme işlemlerine benzer şekilde çalışır.

# %% [markdown]
# <h2 style="
# background-color:#eef6f1;
# color:#1f4d3a;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📙 Kümelerin Oluşturulması
# </h2>

# %%
#list → set: listedeki tekrar eden elemanlar kaldırılır

L=[1,"a",123]   #list tanımlandı
S=set(L)        #kümeye dönüştürüldü
S
# Out:
# {1, 123, 'a'}

# %%
#tuple → set: aynı mantık, elemanlar tekilleştirilir

T=("a","ali")
S=set(T)
S
# Out:
# {'a', 'ali'}

# %%
#string → set: karakterler tekilleştirilir

ad="naaciye"
S=set(ad)
S
# Out:
# {'a', 'c', 'e', 'i', 'n', 'y'}

# %% [markdown]
# <h2 style="
# background-color:#eef6f1;
# color:#1f4d3a;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📙 Kümelerin Eleman Sayısını Bulma
# </h2>

# %%
T=("a","ali")
S=set(T)
len(S) # Çıktı: 3
# Out:
# 2

# %% [markdown]
# <h2 style="
# background-color:#eef6f1;
# color:#1f4d3a;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📙 Kümelerdeki Elemana Erişme
# </h2>

# %%
#SIRASIZ olduğu için doğrudan indeksle erişim yapılamaz.
# Ancak elemanlar döngü ile işlenebilir.
T=("a","ali")
S=set(T)
for eleman in S:
    print(eleman, end=" ")
# Out:
# ali a

# %%
ad="naaciye"
S=set(ad)
# Set'i listeye çevirerek indeksle erişim
S_liste = list(S)
print(S_liste) # Çıktı: ['n', 'a', 'c', 'i', 'y', 'e'] (sıra değişebilir)
print(S_liste[0]) # Örnek: 'n' (sıra değişebilir)
# Out:
# ['i', 'a', 'e', 'c', 'y', 'n']
# i

# %% [markdown]
# <h2 style="
# background-color:#eef6f1;
# color:#1f4d3a;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📙 Kümelerdeki Elemanı Silme
# </h2>

# %%
ad="naaciye"
S=set(ad)
S.discard('a') # 'a' elemanını siler, eleman yoksa hata vermez
S
# Out:
# {'c', 'e', 'i', 'n', 'y'}

# %%
ad="naaciye"
S=set(ad)
S.remove('a') # 'a' elemanını siler, eleman yoksa hata vermez
S
# Out:
# {'c', 'e', 'i', 'n', 'y'}

# %%
ad="naaciye"
S=set(ad)

#Set'in tamamını temizleme
S.clear()
print(S) # Çıktı: set()
# Out:
# set()

# %% [markdown]
# <h2 style="
# background-color:#eef6f1;
# color:#1f4d3a;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📙 Kümelerdeki Elemanları Ekrana Yazdırma
# </h2>

# %%
ad="naaciye"
S=set(ad)
print(S)
# Out:
# {'i', 'a', 'e', 'c', 'y', 'n'}

# %% [markdown]
# <h2 style="
# background-color:#eef6f1;
# color:#1f4d3a;
# padding:14px 18px;
# border-radius:12px;
# font-weight:700;">
# 📙 Kümelerdeki Elemanların Değiştirilmesi
# </h2>

# %%
#Eleman değiştirme (önce eski elemanı kaldır, sonra yenisini ekle)
T=("a","ali")
S=set(T)
S.add("b")
S #{'a', 'ali', 'b'}
S.update([8,"l"]) #birden fazla eleman ekler
S #{8, 'a', 'ali', 'l'}
# Out:
# {8, 'a', 'ali', 'b', 'l'}
