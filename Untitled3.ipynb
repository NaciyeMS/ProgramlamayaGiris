# %%
ad=input("adınızı girin")
print(ad)
# Out:
# adınızı girin naciye
# naciye

# %%
sayi=input("bir sayi girin")
print("girdiğiniz sayi:"+sayi*3)
# Out:
# bir sayi girin 5
# girdiğiniz sayi:555

# %%
#♠tür dönüşümü 
ad="5"  #string metinsel ifadedir
sayi=int( ad)
print(sayi*3)
# Out:
# 15

# %%
sayi=float( input("bir ondalıklı sayi girin"))
print(sayi*3)
# Out:
# bir ondalıklı sayi girin 45.3
# 135.89999999999998

# %%
a,b,c= input("üç sayı girin").split()
print("girdiğiniz a değeri"+a)
print("girdiğiniz b değeri"+b)
print("girdiğiniz c değeri"+c)
# Out:
# üç sayı girin 3 9 6
# girdiğiniz a değeri3
# girdiğiniz b değeri9
# girdiğiniz c değeri6

# %%
sayi1=float( input("birinci sayıyı girin"))
sayi2=float(input("ikinci sayıyı girin"))
print("Girilen sayıların toplamı:" ,(sayi1+sayi2))
print("Girilen sayıların farkı:" , (sayi1-sayi2))
print("Girilen sayıların çarpımı:" ,(sayi1*sayi2))
print("Girilen sayıların bölümü:" ,(sayi1/sayi2))
print("Girilen sayıların kalanı:" ,(sayi1%sayi2))
# Out:
# birinci sayıyı girin 8
# ikinci sayıyı girin 6
# Girilen sayıların toplamı: 14.0
# Girilen sayıların farkı: 2.0
# Girilen sayıların çarpımı: 48.0
# Girilen sayıların bölümü: 1.3333333333333333
# Girilen sayıların kalanı: 2.0

# %%
"""
1. başla
2. bir sayı giriniz" ey
3. oku x
4. eğer x>10 eY büyük
değilse ey küüçük"""

# %%
vize=float(input("vize notunuzu girin"))
final=float(input("final notunuzu girin"))
ortalama=vize*0.4+final*0.6
print("ortalama:", ortalama)
if ortalama>=60:
    print("geçti")
else:
    print("kaldı")
# Out:
# vize notunuzu girin 52
# final notunuzu girin 62
# ortalama: 58.0
# kaldı
