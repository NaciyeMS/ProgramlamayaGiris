# %% [markdown]
# <center>
# <div style="background: linear-gradient(135deg, #2563eb, #1d4ed8, #3b82f6);
#             color:white;
#             padding:28px;
#             border-radius:20px;
#             font-size:38px;
#             font-weight:900;
#             font-family:'Trebuchet MS', sans-serif;
#             letter-spacing:1.5px;
#             text-shadow:2px 2px 8px rgba(0,0,0,0.3);
#             box-shadow: 3px 3px 12px rgba(0,0,0,0.25);
#             width:fit-content;">
# 💻🧠 PROGRAMLAMAYA GİRİŞ DERS 2
# </div>
# </center>
#
# ---
#
# ## 📘 DERS 2
#
# ## 📚 İÇİNDEKİLER
#
# <div style="background-color:#f8fafc; padding:20px; border-radius:15px; box-shadow:2px 2px 10px rgba(0,0,0,0.05); font-size:18px; line-height:1.8;">
#
# 🔹 **ARİTMETİK OPERATÖRLER (- + / * %)**
# 🔹 **ATAMA OPERATÖRÜ(=)**
# 🔹 **BİRLEŞİK ATAMA OPERATÖRLERİ(+=, -=, /=....)**
# 🔹 **ARTIRMA AZALTMA OPERATÖRLERİ** <br>
# 🔹 **💡 SORULAR**<br>
# 🔹 **💡 CEVAPLAR**<BR>
# 🔹 **KARŞILAŞTIRMA OPERATÖRÜ**<br>
# 🔹 **MANTIKSAL OPERATÖRLER**
# </div>

# %% [markdown]
# <div style="background-color:#F87171;
#             color:white;
#             padding:16px;
#             border-radius:15px;
#             text-align:center;
#             font-size:26px;
#             font-weight:bold;
#             box-shadow: 2px 2px 10px rgba(0,0,0,0.2);">
#
# 🧮 ARİTMETİK OPERATÖRLER
# </div>

# %% [markdown]
# Python’da aritmetik işlemleri yapmak için kullanılan temel operatörlerdir.
# Sayısal veri tipleri üzerinde işlem yaparlar (**int**, **float**).
#
# | **Operatör** | **Adı**          | **Kullanım** | **Açıklama**                                      |
# |--------------|------------------|--------------|--------------------------------------------------|
# | `+`          | Toplama          | `a + b`      | İki sayıyı toplar                                |
# | `-`          | Çıkarma          | `a - b`      | Sayıları çıkarır                                 |
# | `*`          | Çarpma           | `a * b`      | Sayıları çarpar                                  |
# | `/`          | Bölme            | `a / b`      | Ondalıklı sonuç döner (`float`)                  |
# | `//`         | Tamsayı Bölme    | `a // b`     | Sonucu aşağı yuvarlayarak tamsayı verir          |
# | `%`          | Mod (Kalan)      | `a % b`      | Bölme işleminden kalan sonucu verir              |
# | `**`         | Üs Alma          | `a ** b`     | `a` üzeri `b` işlemini yapar                     |
#
# ---
#
# ### ✔️ Örnekler

# %%
print(7 + 3)   # 10
# Out:
# 10

# %%
print(7 - 3)   # 4
# Out:
# 4

# %%
print(7 * 3)   # 21
# Out:
# 21

# %%
print(7 / 3)   # 2.333...
# Out:
# 2.3333333333333335

# %%
print(7 // 3)  # 2
# Out:
# 2

# %%
print(7 % 3)   # 1
# Out:
# 1

# %%
print(2 ** 5)  # 32
# Out:
# 32

# %% [markdown]
# <div style="background-color:#FBBF24;
#             color:white;
#             padding:16px;
#             border-radius:15px;
#             text-align:center;
#             font-size:26px;
#             font-weight:bold;
#             box-shadow: 2px 2px 10px rgba(0,0,0,0.2);">
#
# 🟦 ATAMA OPERATÖRÜ
# </div>

# %% [markdown]
# Python’da `=` operatörü **atama operatörüdür**.
# Bir değişkene değer yüklemek için kullanılır.
# | **Operatör** | **Adı**         | **Kullanım** | **Açıklama**                          |
# | ------------ | --------------- | ------------ | ------------------------------------- |
# | `=`          | Atama Operatörü | `x = 5`      | Sağdaki değeri soldaki değişkene atar |
#
#
# ### 📌 Temel Kullanım
#
# ```python
#
# isim = "Ali"
# pi = 3.14

# %%
x = 10
print(x)
# Out:
# 10

# %%
a = 7
b = a      # b artık 7 değerini alır
c = b + 3  # c = 10 olur
print(a, b, c)
# Out:
# 7 7 10

# %% [markdown]
# <div style="background-color:#FACC15;
#             color:white;
#             padding:16px;
#             border-radius:15px;
#             text-align:center;
#             font-size:26px;
#             font-weight:bold;
#             box-shadow: 2px 2px 10px rgba(0,0,0,0.2);">
#
#  🟩  BİRLEŞİK ATAMA OPERATÖRÜ (Compound Assignment)
# </div>

# %% [markdown]
# ## 🟩 Python Birleşik Atama Operatörleri (Compound Assignment)
#
# Birleşik atama operatörleri, bir değişkenin mevcut değerini işlem yaparak **kısa yoldan güncellemek** için kullanılır.
# `x = x + 5` yerine `x += 5` yazmak gibi.
#
# ---
#
# ### 📌 Temel Mantık
#
# ```python
# x += 3   # x = x + 3
# x *= 2   # x = x * 2

# %% [markdown]
# | **Operatör** | **Kullanım** | **Açıklama**                        |                  |
# | ------------ | ------------ | ----------------------------------- | ---------------- |
# | `+=`         | `x += 5`     | `x = x + 5` → Toplayarak ata        |                  |
# | `-=`         | `x -= 2`     | `x = x - 2` → Çıkararak ata         |                  |
# | `*=`         | `x *= 3`     | `x = x * 3` → Çarparak ata          |                  |
# | `/=`         | `x /= 2`     | `x = x / 2` → Bölerek ata (*float*) |                  |
# | `//=`        | `x //= 2`    | `x = x // 2` → Tamsayı böl          |                  |
# | `%=`         | `x %= 3`     | `x = x % 3` → Kalanı ata            |                  |
# | `**=`        | `x **= 2`    | `x = x ** 2` → Üs alarak ata        |                  |

# %%
x = 20
x -= 7   # x = x - 7
print(x)  # 13
# Out:
# 13

# %%
x = 6
x *= 4   # x = x * 4
print(x)  # 24
# Out:
# 24

# %%
x = 15
x /= 4   # x = x / 4
print(x)  # 3.75
# Out:
# 3.75

# %%
x = 17
x //= 3   # x = x // 3
print(x)  # 5
# Out:
# 5

# %%
x = 17
x %= 5   # x = x % 5
print(x)  # 2
# Out:
# 2

# %%
x = 2
x **= 5    # x = x ** 5
print(x)   # 32
# Out:
# 32

# %% [markdown]
# <div style="background-color:#34D399;
#             color:white;
#             padding:16px;
#             border-radius:15px;
#             text-align:center;
#             font-size:26px;
#             font-weight:bold;
#             box-shadow: 2px 2px 10px rgba(0,0,0,0.2);">
#
# 🔼⬇️ ARTIRMA & AZALTMA OPERATÖRLERİ (INCREMENT & DECREMENT OPERATORS)
# </div>

# %% [markdown]
# Python’da C, C++, Java gibi `++` veya `--` operatörleri **yoktur**.
# Bunun yerine artırma ve azaltma işlemleri **birleşik atama operatörleri `+=` ve `-=`** ile yapılır.
#
# ### ✔️ Temel Kullanım
#
# #### 🔼 Artırma (Increment)
# ```python
# x = 5
# x += 1    # x = x + 1
# print(x)  # 6

# %%
y = 10
y -= 1    # y = y - 1
print(y)  # 9
# Out:
# 9

# %% [markdown]
# <div style="background-color:#FBBF24;
#             color:#1F2937;
#             padding:16px;
#             border-radius:15px;
#             text-align:center;
#             font-size:28px;
#             font-weight:bold;
#             box-shadow:2px 2px 10px rgba(0,0,0,0.2);">
# ❓ PYTHON / PROGRAMLAMA SORULARI
# </div>

# %% [markdown]
# # ❓ SORU 1
#
# ---
#
# **Soru:**
# Kullanıcıdan alınan iki değerin **toplamını, farkını, çarpımını, bölümünü ve kalanını** ekrana yazdıran bir Python programı yazınız.
#
# **İpucu (Opsiyonel):**
# - `input()` fonksiyonu ile kullanıcıdan veri alınabilir.
# - Aritmetik operatörler: `+`, `-`, `*`, `/`, `%`.
#
# ---
#
# ### 🔹 Örnek Girdi / Çıktı
#
# ```python
# # Girdi
# a = 12
# b = 5
#
# # Beklenen Çıktı
# # Toplam: 17
# # Fark: 7
# # Çarpım: 60
# # Bölüm: 2.4
# # Kalan: 2

# %%
# Buraya kendi çözüm kodunuzu yazın

# %% [markdown]
# # ❓ SORU 2
# ---
#
# **Soru:**
# Kullanıcıdan alınan dikdörtgenin **A ve B kenar uzunluklarına** göre **çevresini ve alanını** hesaplayan bir Python programı yazınız.
#
# **İpucu (Opsiyonel):**
# - `input()` fonksiyonu ile kullanıcıdan veri alınabilir.
# - Çevre: `(A + B) * 2`
# - Alan: `A * B`
#
# ---
#
# ### 🔹 Örnek Girdi / Çıktı
#
# ```python
# # Girdi
# A = 5
# B = 7
#
# # Beklenen Çıktı
# # Çevre: 24
# # Alan: 35

# %%
# Buraya kendi çözüm kodunuzu yazın

# %% [markdown]
# # ❓ SORU 3
# ---
#
# **Soru:**
# Çapı kullanıcıdan alınan bir dairenin **çevresini ve alanını** hesaplayıp ekrana yazan bir Python programı yazınız.
#
# **İpucu (Opsiyonel):**
# - `PI` sayısını **sabit** olarak tanımlayın: `PI = 3.14`
# - Çevre: `2 * PI * r`
# - Alan: `PI * r * r`
# - Hesaplanan değerler **ondalık sayı (float)** olarak ekrana yazılmalı.
#
# ---
#
# ### 🔹 Örnek Girdi / Çıktı
#
# ```python
# # Girdi
# PI = 3.14
# r = 5  # yarıçap (çap / 2)
#
# # Beklenen Çıktı
# # Çevre: 31.400000
# # Alan: 78.500000

# %%
# Buraya kendi çözüm kodunuzu yazın

# %% [markdown]
# <div style="background-color:#FBBF24;
#             color:#1F2937;
#             padding:16px;
#             border-radius:15px;
#             text-align:center;
#             font-size:28px;
#             font-weight:bold;
#             box-shadow:2px 2px 10px rgba(0,0,0,0.2);">
# ❓ PYTHON / PROGRAMLAMA SORULARININ CEVAPLARI
#
# </div>

# %%
##SORU 1
# Kullanıcıdan iki sayı alalım
a = 12
b = 5

# İşlemler
toplam = a + b
fark = a - b
carpim = a * b
bolum = a / b
kalan = a % b

# Sonuçları ekrana yazdırma
print("Toplam:", toplam)
print("Fark:", fark)
print("Çarpım:", carpim)
print("Bölüm:", bolum)
print("Kalan:", kalan)
# Out:
# Toplam: 17
# Fark: 7
# Çarpım: 60
# Bölüm: 2.4
# Kalan: 2

# %%
##SORU 2
# Dikdörtgenin kenar uzunlukları
A = 5
B = 7

# Çevre ve alan hesaplama
cevre = (A + B) * 2
alan = A * B

# Sonuçları ekrana yazdırma
print("Çevre:", cevre)
print("Alan:", alan)
# Out:
# Çevre: 24
# Alan: 35

# %%
##SORU 3
# Sabit PI tanımlanıyor
PI = 3.14

# Çap verisi
cap = 10

# Yarıçap hesaplanıyor
r = cap / 2

# Çevre ve alan hesaplanıyor
cevre = 2 * PI * r
alan = PI * r * r

# Sonuçlar ekrana yazdırılıyor
print("Çevre:", cevre)
print("Alan:", alan)
# Out:
# Çevre: 31.400000000000002
# Alan: 78.5

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #3B82F6, #10B981);
#     color:white;
#     padding:16px;
#     border-radius:15px;
#     text-align:center;
#     font-size:26px;
#     font-weight:bold;
#     box-shadow: 2px 2px 10px rgba(0,0,0,0.2);
# ">
# 🔍 KARŞILAŞTIRMA OPERATÖRLERİ (COMPARISON OPERATORS)
# </div>

# %% [markdown]
# ### 📘 Python Karşılaştırma Operatörleri
#
# | Operatör | Açıklama | Örnek |
# |---------|----------|-------|
# | `==` | Eşit mi? | `5 == 5 → True` |
# | `!=` | Eşit değil mi? | `5 != 3 → True` |
# | `>` | Büyük mü? | `7 > 2 → True` |
# | `<` | Küçük mü? | `3 < 8 → True` |
# | `>=` | Büyük veya eşit mi? | `6 >= 6 → True` |
# | `<=` | Küçük veya eşit mi? | `4 <= 9 → True` |

# %%
a = 10
b = 7

print("a == b :", a == b)
print("a != b :", a != b)
print("a > b  :", a > b)
print("a < b  :", a < b)
print("a >= b :", a >= b)
print("a <= b :", a <= b)
# Out:
# a == b : False
# a != b : True
# a > b  : True
# a < b  : False
# a >= b : True
# a <= b : False

# %% [markdown]
# ### 📘 EŞİTTİR OPERATÖRÜ (==)
#
# #### ✔ AÇIKLAMA
# İki değerin **eşit olup olmadığını** kontrol eder.
# Sonuç olarak **True** veya **False** döndürür.

# %%
# Sabit sayılar
a = 5
b = 7
c = 5

# Eşitlik kontrolü
print("Sonuç :", a == c)

# Eşitlik kontrolü
print("Sonuç :", a == b)
# Out:
# Sonuç : True
# Sonuç : False

# %%
# Sabit metinler
metin1 = "Merhaba"
metin2 = "merhaba"
metin3 = "Merhaba"
# Eşitlik kontrolü
print("Sonuç : ", metin1 == metin3)

# Eşitlik kontrolü
print("Sonuç : ", metin1 == metin2)

# Not: Metinlerde BÜYÜK/KÜÇÜK harf duyarlılığı vardır
# Out:
# Sonuç :  True
# Sonuç :  False

# %% [markdown]
# ### 📘 EŞİT DEĞİL OPERATÖRÜ (!=)
#
# #### ✔ AÇIKLAMA
# İki değerin **eşit olmadığını** kontrol eder.
# Sonuç olarak **True** veya **False** döndürür.

# %%
# Sabit sayılar
a = 5
b = 7
c = 5

# Eşit değil kontrolü
print("Sonuç :", a != c)

# Eşit değil kontrolü
print("Sonuç :", a != b)
# Out:
# Sonuç : False
# Sonuç : True

# %%
# Sabit metinler
metin1 = "Merhaba"
metin2 = "merhaba"
metin3 = "Merhaba"
# Eşitlik kontrolü
print("Sonuç : ", metin1 != metin3)

# Eşitlik kontrolü
print("Sonuç : ", metin1 != metin2)

# Not: Metinlerde BÜYÜK/KÜÇÜK harf duyarlılığı vardır
# Out:
# Sonuç :  False
# Sonuç :  True

# %% [markdown]
# ### 📘 BÜYÜKTÜR OPERATÖRÜ (>)
#
# #### ✔ AÇIKLAMA
# Sol değerin sağ değerden **büyük olup olmadığını** kontrol eder.
# Sonuç olarak **True** veya **False** döndürür.

# %%
# Sabit sayılar
a = 5
b = 7
c = 5

# Büyüktür kontrolü
print("a > c :", a > c)

# Büyüktür kontrolü
print("a > b :", a > b)

# Büyüktür kontrolü
print("b > a :", b > a)
# Out:
# a > c : False
# a > b : False
# b > a : True

# %% [markdown]
# ### 📘 KÜÇÜKTÜR OPERATÖRÜ (<)
#
# #### ✔ AÇIKLAMA
# Sol değerin sağ değerden **küçük olup olmadığını** kontrol eder.
# Sonuç olarak **True** veya **False** döndürür.

# %%
# Sabit sayılar
a = 5
b = 7
c = 5

# Küçüktür kontrolü
print("a < c :", a < c)

# Küçüktür kontrolü
print("a < b :", a < b)

# Küçüktür kontrolü
print("b < a :", b < a)
# Out:
# a < c : False
# a < b : True
# b < a : False

# %% [markdown]
# ### 📘 BÜYÜK VEYA EŞİTTİR OPERATÖRÜ (>=)
#
# #### ✔ AÇIKLAMA
# Sol değerin sağ değerden **büyük veya eşit olup olmadığını** kontrol eder.
# Sonuç olarak **True** veya **False** döndürür.

# %%
# Sabit sayılar
a = 5
b = 7
c = 5

# Büyük veya eşittir kontrolü
print("a >= c :", a >= c)

# Büyük veya eşittir kontrolü
print("a >= b :", a >= b)

# Büyük veya eşittir kontrolü
print("b >= a :", b >= a)
# Out:
# a >= c : True
# a >= b : False
# b >= a : True

# %% [markdown]
# ### 📘 KÜÇÜK VEYA EŞİTTİR OPERATÖRÜ (<=)
#
# #### ✔ AÇIKLAMA
# Sol değerin sağ değerden **küçük veya eşit olup olmadığını** kontrol eder.
# Sonuç olarak **True** veya **False** döndürür.

# %%
# Sabit sayılar
a = 5
b = 7
c = 5

# Küçük veya eşittir kontrolü
print("a <= c :", a <= c)

# Küçük veya eşittir kontrolü
print("a <= b :", a <= b)

# Küçük veya eşittir kontrolü
print("b <= a :", b <= a)
# Out:
# a <= c : True
# a <= b : True
# b <= a : False

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #F59E0B, #EF4444);
#     color:white;
#     padding:16px;
#     border-radius:15px;
#     text-align:center;
#     font-size:26px;
#     font-weight:bold;
#     box-shadow: 2px 2px 10px rgba(0,0,0,0.2);
# ">
# 🔗 MANTIKSAL OPERATÖRLER (LOGICAL OPERATORS)
# </div>

# %% [markdown]
# | Operatör | Açıklama                                        | Örnek                    |
# | -------- | ----------------------------------------------- | ------------------------ |
# | `and`    | Her iki ifade **True** ise True döner           | `True and False → False` |
# | `or`     | İki ifadeden **en az biri True** ise True döner | `True or False → True`   |
# | `not`    | Boolean değerin tersini alır                    | `not True → False`       |

# %% [markdown]
# ### 📘 AND OPERATÖRÜ (and) DOĞRULUK TABLOSU (0 ve 1 ile)
#
# | X (bool) | Y (bool) | X and Y (bool) | X (0/1) | Y (0/1) | X and Y (0/1) |
# |-----------|-----------|----------------|----------|----------|----------------|
# | True      | True      | True           | 1        | 1        | 1              |
# | True      | False     | False          | 1        | 0        | 0              |
# | False     | True      | False          | 0        | 1        | 0              |
# | False     | False     | False          | 0        | 0        | 0              |

# %%
x = True
y = False

# AND operatörü
print("x and y :", x and y)
# Out:
# x and y : False

# %% [markdown]
# ### 📘 OR OPERATÖRÜ (or) DOĞRULUK TABLOSU (0 ve 1 ile)
#
# | X (bool) | Y (bool) | X or Y (bool) | X (0/1) | Y (0/1) | X or Y (0/1) |
# |-----------|-----------|---------------|----------|----------|---------------|
# | True      | True      | True          | 1        | 1        | 1             |
# | True      | False     | True          | 1        | 0        | 1             |
# | False     | True      | True          | 0        | 1        | 1             |
# | False     | False     | False         | 0        | 0        | 0             |

# %%
x = True
y = False
# OR operatörü
print("x or y :", x or y)
# Out:
# x or y : True

# %% [markdown]
# ### 📘 NOT OPERATÖRÜ (not) DOĞRULUK TABLOSU (0 ve 1 ile)
#
# | X (bool) | not X (bool) | X (0/1) | not X (0/1) |
# |-----------|--------------|----------|-------------|
# | True      | False        | 1        | 0           |
# | False     | True         | 0        | 1           |

# %%
x = True
y = False

# NOT operatörü
print("not x :", not x)      
print("not y :", not y)
# Out:
# not x : False
# not y : True

# %% [markdown]
# ### ❓ SORU — Mantıksal ve Karşılaştırma Operatörleri
#
# **Verilen değişkenler:**
#
# ```python
# x = 7
# y = 5
# z = 7
# ## Soru:
# Aşağıdaki ifadelerin ekran çıktısı ne olur?
#
# x == z and y < x
#
# x != y or y > z
#
# not(x > z)
#
# (x == y) or (y < z and x == z)

# %%
x = 7
y = 5
z = 7
x == z and y < x
# Out:
# True

# %%
x = 7
y = 5
z = 7
x != y or y > z
# Out:
# True

# %%
x = 7
y = 5
z = 7
not(x > z)
# Out:
# True

# %%
x = 7
y = 5
z = 7
not(x > z)
# Out:
# True
